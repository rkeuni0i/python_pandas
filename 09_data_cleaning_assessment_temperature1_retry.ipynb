# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#1번 문제 
df = pd.read_csv("./data/temperatures.csv", encoding="utf-8")
print(df)
#2번 문제
print(df.duplicated(keep=False).sum())
#3번 문제
df = df.drop_duplicates()
print(df)
#4번 문제
print(df.isnull().sum())
#5번 문제
df.dropna(how='any', axis=0,inplace=True)
print(df)
#6번 문제 
df['날짜'] = pd.to_datetime(df['날짜'])
#7번 문제
dfDate = df.groupby(df['날짜'].dt.year)['기온'].mean()
reindexdata = dfDate.reset_index()
print(reindexdata)
#8번 문제
new_df= reindexdata.query("날짜 >= 1985 and 날짜 <=1990")
#9번 문제 
plt.rcParams['font.family']='malgun gothic'
plt.figure(figsize=(10,6))
plt.title("년도별 평균 기온", color = "yellow", size=20)
color = ['b','orange','green','r','purple','brown']
sns.barplot(data = new_df, x= new_df['날짜'], y = new_df['기온'], errwidth=0, palette = color)
sns.pointplot(data =new_df, x= new_df['날짜'], y = new_df['기온'], errwidth=0)
plt.draw()
plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# Out:
# /tmp/ipykernel_11528/1952025663.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = new_df, x= new_df['날짜'], y = new_df['기온'], errwidth=0, palette = color)
# /tmp/ipykernel_11528/1952025663.py:31: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.barplot(data = new_df, x= new_df['날짜'], y = new_df['기온'], errwidth=0, palette = color)
# /tmp/ipykernel_11528/1952025663.py:32: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   sns.pointplot(data =new_df, x= new_df['날짜'], y = new_df['기온'], errwidth=0)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
#               날짜    기온
# 0     1981-01-02  17.9
# 1     1981-01-03  18.8
# 2     1981-01-04  14.6
# 3     1981-01-05  15.8
# 4     1981-01-06  15.8
# ...          ...   ...
# 3655  1990-12-28  13.6
# 3656  1990-12-29  13.5
# 3657  1990-12-30  15.7
# 3658  1990-12-31  13.0
# 3659  1990-12-31  13.0
#
# [3660 rows x 2 columns]
# 6
#               날짜    기온
# 0     1981-01-02  17.9
# 1     1981-01-03  18.8
# 2     1981-01-04  14.6
# 3     1981-01-05  15.8
# 4     1981-01-06  15.8
# ...          ...   ...
# 3654  1990-12-27  14.0
# 3655  1990-12-28  13.6
# 3656  1990-12-29  13.5
# 3657  1990-12-30  15.7
# 3658  1990-12-31  13.0
#
# [3657 rows x 2 columns]
# 날짜    0
# 기온    8
# dtype: int64
#               날짜    기온
# 0     1981-01-02  17.9
# 1     1981-01-03  18.8
# 2     1981-01-04  14.6
# 3     1981-01-05  15.8
# 4     1981-01-06  15.8
# ...          ...   ...
# 3654  1990-12-27  14.0
# 3655  1990-12-28  13.6
# 3656  1990-12-29  13.5
# 3657  1990-12-30  15.7
# 3658  1990-12-31  13.0
#
# [3649 rows x 2 columns]
#      날짜         기온
# 0  1981  11.492033
# 1  1982  10.783562
# 2  1983  11.187397
# 3  1984  10.591781
# 4  1985  11.137534
# 5  1986  10.803288
# 6  1987  10.853151
# 7  1988  11.972055
# 8  1989  11.261918
# 9  1990  11.669589
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   plt.draw()
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   plt.draw()
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   plt.draw()
# /tmp/ipykernel_11528/1952025663.py:33: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from font(s) DejaVu Sans.
#   plt.draw()
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# /tmp/ipykernel_11528/1952025663.py:34: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from font(s) DejaVu Sans.
#   plt.savefig("./images/bar_point_chat.jpg", dpi= 300)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:158: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
# findfont: Font family 'malgun gothic' not found.
