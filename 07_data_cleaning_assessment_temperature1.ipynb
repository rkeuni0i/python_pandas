# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./data/temperatures.csv", encoding="utf-8")
df.duplicated(keep=False).sum()
df=df.drop_duplicates()
df.isnull().sum()
df.dropna(subset=['기온'], inplace=True)
df['날짜']= pd.to_datetime(df['날짜'])
dfDate = df.groupby(df['날짜'].dt.year)['기온'].mean()
reindexdata = dfDate.reset_index()
newdata = reindexdata.query('날짜 >= 1985 & 날짜 <=1990')
newdata
# Out:
#      날짜         기온
# 4  1985  11.137534
# 5  1986  10.803288
# 6  1987  10.853151
# 7  1988  11.972055
# 8  1989  11.261918
# 9  1990  11.669589

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(8,6))
color = ['blue','orange','green','magneta','purple','brown']
sns.barplot(data=newdata, x = newdata['날짜'], y= newdata['기온'], errwidth = 0, color = ['b','orange','g','m','purple','brwon'])
sns.pointplot(data=newdata, x = newdata['날짜'], y= newdata['기온'])
plt.xlabel("날짜", fontsize=8)
plt.ylabel("기온", fontsize=8)
plt.title("년도별 평균 기온", color="yellow", fontsize=20)
plt.draw()
plt.savefig("./images/picturepng", dip=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 plt.rcParams['font.family'] = 'Malgun Gothic'
#       2 plt.figure(figsize=(8,6))
#       3 color = ['blue','orange','green','magneta','purple','brown']
# ----> 4 sns.barplot(data=newdata, x = newdata['날짜'], y= newdata['기온'], errwidth = 0, color = ['b','orange','g','m','purple','brwon'])
#       5 sns.pointplot(data=newdata, x = newdata['날짜'], y= newdata['기온'])
#       6 plt.xlabel("날짜", fontsize=8)
#       7 plt.ylabel("기온", fontsize=8)
#
# File /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:2371, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
# ...
